# %%
import pandas as pd

# %%
df = pd.DataFrame(
    [
     {'Filhos':1, 'Sexo': 'M', 'Estado Civil': 'Casado'},
     {'Filhos':2, 'Sexo': 'F', 'Estado Civil': 'Casado'},
     {'Filhos':5, 'Sexo': 'F', 'Estado Civil': 'Casado'},
     {'Filhos':0, 'Sexo': 'F', 'Estado Civil': 'Casado'},
     {'Filhos':6, 'Sexo': 'M', 'Estado Civil': 'Casado'},
     {'Filhos':3, 'Sexo': 'M', 'Estado Civil': 'Casado'},


    ]
)

# %%
df
# Out:
#    Filhos Sexo Estado Civil
# 0       1    M       Casado
# 1       2    F       Casado
# 2       5    F       Casado
# 3       0    F       Casado
# 4       6    M       Casado
# 5       3    M       Casado

# %%
df['Filhos'] + 100
# Out:
# 0    101
# 1    102
# 2    105
# 3    100
# 4    106
# 5    103
# Name: Filhos, dtype: int64

# %%
sexo = {'M': 0, 'F': 1}

# %%
df['Sexo'] = df['Sexo'].map(sexo)

# %%
df
# Out:
#    Filhos  Sexo Estado Civil
# 0       1     0       Casado
# 1       2     1       Casado
# 2       5     1       Casado
# 3       0     1       Casado
# 4       6     0       Casado
# 5       3     0       Casado

# %%
estado = {'Casado': 1}

# %%
df['Estado Civil'] = df['Estado Civil'].map(estado)

# %%
df
# Out:
#    Filhos  Sexo  Estado Civil
# 0       1     0             1
# 1       2     1             1
# 2       5     1             1
# 3       0     1             1
# 4       6     0             1
# 5       3     0             1

# %%
df.rename(columns = {'Estado Civil':'Estado'})
# Out:
#    Filhos  Sexo  Estado
# 0       1     0       1
# 1       2     1       1
# 2       5     1       1
# 3       0     1       1
# 4       6     0       1
# 5       3     0       1

# %%
for index, row in df.iterrows():
   if row['Filhos'] > 0 :
       df.loc[index, 'Filhos'] = '1'
   else:
       df.loc[index, 'Filhos'] = '0'

# %%
df
# Out:
#   Filhos  Sexo  Estado Civil
# 0      1     0             1
# 1      1     1             1
# 2      1     1             1
# 3      0     1             1
# 4      1     0             1
# 5      1     0             1

# %%
pd.DataFrame([
    {'Nome': 'Jetta Variant', 'Motor': 'Motor 4.0 Turbo', 'Ano': 2003, 'Quilometragem': 44410.0, 'Zero_km': False, 'Valor': 88078.64},
    {'Nome': 'Passat', 'Motor': 'Motor Diesel', 'Ano': 1991, 'Quilometragem': 5712.0, 'Zero_km': False, 'Valor': 106161.94},
    {'Nome': 'Crossfox', 'Motor': 'Motor Diesel V8', 'Ano': 1990, 'Quilometragem': 37123.0, 'Zero_km': False, 'Valor': 72832.16}
])
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %%
pd.DataFrame({
    'Crossfox': {'km': 35000, 'ano': 2005}, 
    'DS5': {'km': 17000, 'ano': 2015}, 
    'Fusca': {'km': 130000, 'ano': 1979}, 
    'Jetta': {'km': 56000, 'ano': 2011}, 
    'Passat': {'km': 62000, 'ano': 1999}
})
# Out:
#      Crossfox    DS5   Fusca  Jetta  Passat
# km      35000  17000  130000  56000   62000
# ano      2005   2015    1979   2011    1999

# %%
coisas = pd.DataFrame({'Cor':[1,2,3],
              'Nome':['Azul','Amerelo','Preto'],
               'Objeto':['Mar','Sol','Noite']})
coisas
# Out:
#    Cor     Nome Objeto
# 0    1     Azul    Mar
# 1    2  Amerelo    Sol
# 2    3    Preto  Noite

# %%
data = [[1,2,3],[4,5,6],[7,8,9]]

pd.DataFrame(data = data, columns = 'A B C'.split())
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
dados = pd.read_csv('C:/Users/vitor/Desktop/Estudos/Pessoas.csv',encoding='UTF-8',sep=',')
dados
# Out:
#        Nome   Sobrenome                        Email  Idade          Cidade  \
# 0     Vitor      Duarte    vitor.duartegot@gmail.com     21       São Paulo
# 1    Amanda     Roberta  amanda.robertinha@gmail.com     25       São Paulo
# 2     Pedro       Souza      pedro147.souz@gmail.com     28  Rio de Janeiro
# 3  Priscila     Pereira  priscila.pereira7@gmail.com     30    Porto Seguro
# 4   Joaquim      Vieira     joaq.vieira256@gmail.com     23  Belo Horizonte
# 5    Thiago       Alvim      alvins.titi28@gmail.com     28   Florianópolis
# 6     Bruna       Silva        Brunasisi44@gmail.com     27       São Paulo
# 7  Fernando  Diamantino  Fernandin.diam878@gmail.com     23    Porto Alegre
# 8     Paula   Fernandes       paulaF.nades@gmail.com     29           Belém
# 9    Thiago   Guimarães     guimares.tiago@gmail.com     35       São Paulo
#
#   Filhos  Altura        Atuação
# 0      N    1.80     Tecnologia
# 1      N    1.70          Saúde
# 2      S    1.74  Meio Ambiente
# ...

# %% [markdown]
# # Selecionando filtros / Removendo filtros/ Adicionando variaveis

# %%
select1 = (dados['Filhos'] == 'N')
filhos_N = dados[select1]
filhos_N
# Out:
#       Nome  Sobrenome                        Email  Idade          Cidade  \
# 0    Vitor     Duarte    vitor.duartegot@gmail.com     21       São Paulo
# 1   Amanda    Roberta  amanda.robertinha@gmail.com     25       São Paulo
# 4  Joaquim     Vieira     joaq.vieira256@gmail.com     23  Belo Horizonte
# 5   Thiago      Alvim      alvins.titi28@gmail.com     28   Florianópolis
# 8    Paula  Fernandes       paulaF.nades@gmail.com     29           Belém
#
#   Filhos  Altura     Atuação
# 0      N    1.80  Tecnologia
# 1      N    1.70       Saúde
# 4      N    1.75  Engenharia
# 5      N    1.65     Direito
# 8      N    1.80    Esportes

# %%
select1 = (dados.Filhos == 'N') & (dados.Idade > 25)
filhos_N_idade = dados[select1]
filhos_N_idade
# Out:
#      Nome  Sobrenome                    Email  Idade         Cidade Filhos  \
# 5  Thiago      Alvim  alvins.titi28@gmail.com     28  Florianópolis      N
# 8   Paula  Fernandes   paulaF.nades@gmail.com     29          Belém      N
#
#    Altura   Atuação
# 5    1.65   Direito
# 8    1.80  Esportes

# %%
select1 = (dados.Cidade == 'São Paulo') & (dados.Filhos == 'S')
filhos_N = dados[select1]
filhos_N
# Out:
#      Nome  Sobrenome                     Email  Idade     Cidade Filhos  \
# 6   Bruna      Silva     Brunasisi44@gmail.com     27  São Paulo      S
# 9  Thiago  Guimarães  guimares.tiago@gmail.com     35  São Paulo      S
#
#    Altura      Atuação
# 6    1.75         Arte
# 9    1.69  Comunicação

# %%
dados.loc[[0,1,2,3,8],['Nome','Atuação']]
# Out:
#        Nome        Atuação
# 0     Vitor     Tecnologia
# 1    Amanda          Saúde
# 2     Pedro  Meio Ambiente
# 3  Priscila       Medicina
# 8     Paula       Esportes

# %%
select1 = (dados.Cidade == 'São Paulo') & (dados.Filhos == 'S') &  (dados.Altura >= 1.69 )  & (dados.Altura <= 1.75)
filhos_N = dados[select1]
filhos_N
# Out:
#      Nome  Sobrenome                     Email  Idade     Cidade Filhos  \
# 6   Bruna      Silva     Brunasisi44@gmail.com     27  São Paulo      S
# 9  Thiago  Guimarães  guimares.tiago@gmail.com     35  São Paulo      S
#
#    Altura      Atuação
# 6    1.75         Arte
# 9    1.69  Comunicação

# %%
dados.sort_values( by = ['Nome'])
# Out:
#        Nome   Sobrenome                        Email  Idade          Cidade  \
# 1    Amanda     Roberta  amanda.robertinha@gmail.com     25       São Paulo
# 6     Bruna       Silva        Brunasisi44@gmail.com     27       São Paulo
# 7  Fernando  Diamantino  Fernandin.diam878@gmail.com     23    Porto Alegre
# 4   Joaquim      Vieira     joaq.vieira256@gmail.com     23  Belo Horizonte
# 8     Paula   Fernandes       paulaF.nades@gmail.com     29           Belém
# 2     Pedro       Souza      pedro147.souz@gmail.com     28  Rio de Janeiro
# 3  Priscila     Pereira  priscila.pereira7@gmail.com     30    Porto Seguro
# 5    Thiago       Alvim      alvins.titi28@gmail.com     28   Florianópolis
# 9    Thiago   Guimarães     guimares.tiago@gmail.com     35       São Paulo
# 0     Vitor      Duarte    vitor.duartegot@gmail.com     21       São Paulo
#
#   Filhos  Altura        Atuação
# 1      N    1.70          Saúde
# 6      S    1.75           Arte
# 7      S    1.84  Biotecnologia
# ...

# %%
dados
# Out:
#        Nome   Sobrenome                        Email  Idade          Cidade  \
# 0     Vitor      Duarte    vitor.duartegot@gmail.com     21       São Paulo
# 1    Amanda     Roberta  amanda.robertinha@gmail.com     25       São Paulo
# 2     Pedro       Souza      pedro147.souz@gmail.com     28  Rio de Janeiro
# 3  Priscila     Pereira  priscila.pereira7@gmail.com     30    Porto Seguro
# 4   Joaquim      Vieira     joaq.vieira256@gmail.com     23  Belo Horizonte
# 5    Thiago       Alvim      alvins.titi28@gmail.com     28   Florianópolis
# 6     Bruna       Silva        Brunasisi44@gmail.com     27       São Paulo
# 7  Fernando  Diamantino  Fernandin.diam878@gmail.com     23    Porto Alegre
# 8     Paula   Fernandes       paulaF.nades@gmail.com     29           Belém
# 9    Thiago   Guimarães     guimares.tiago@gmail.com     35       São Paulo
#
#   Filhos  Altura        Atuação
# 0      N    1.80     Tecnologia
# 1      N    1.70          Saúde
# 2      S    1.74  Meio Ambiente
# ...

# %%
pd.DataFrame(dados['Idade'].drop_duplicates())
# Out:
#    Idade
# 0     21
# 1     25
# 2     28
# 3     30
# 4     23
# 6     27
# 8     29
# 9     35

# %%
mulheres = ['Amanda','Priscila','Bruna','Paula']
dados['Sexo'] = dados['Nome'].apply(lambda x: 'Mulher' if x in mulheres else 'Homem')

# %%
dados
# Out:
#        Nome   Sobrenome                        Email  Idade          Cidade  \
# 0     Vitor      Duarte    vitor.duartegot@gmail.com     21       São Paulo
# 1    Amanda     Roberta  amanda.robertinha@gmail.com     25       São Paulo
# 2     Pedro       Souza      pedro147.souz@gmail.com     28  Rio de Janeiro
# 3  Priscila     Pereira  priscila.pereira7@gmail.com     30    Porto Seguro
# 4   Joaquim      Vieira     joaq.vieira256@gmail.com     23  Belo Horizonte
# 5    Thiago       Alvim      alvins.titi28@gmail.com     28   Florianópolis
# 6     Bruna       Silva        Brunasisi44@gmail.com     27       São Paulo
# 7  Fernando  Diamantino  Fernandin.diam878@gmail.com     23    Porto Alegre
# 8     Paula   Fernandes       paulaF.nades@gmail.com     29           Belém
# 9    Thiago   Guimarães     guimares.tiago@gmail.com     35       São Paulo
#
#   Filhos  Altura        Atuação    Sexo
# 0      N    1.80     Tecnologia   Homem
# 1      N    1.70          Saúde  Mulher
# ...

# %%
for index, row in dados.iterrows():
   if row['Altura'] <= 1.69 :
       dados.loc[index, 'Situacao'] = 'Baixo'
   else:
       dados.loc[index, 'Situacao'] = 'Alto'

# %%
dados
# Out:
#        Nome   Sobrenome                        Email  Idade          Cidade  \
# 0     Vitor      Duarte    vitor.duartegot@gmail.com     21       São Paulo
# 1    Amanda     Roberta  amanda.robertinha@gmail.com     25       São Paulo
# 2     Pedro       Souza      pedro147.souz@gmail.com     28  Rio de Janeiro
# 3  Priscila     Pereira  priscila.pereira7@gmail.com     30    Porto Seguro
# 4   Joaquim      Vieira     joaq.vieira256@gmail.com     23  Belo Horizonte
# 5    Thiago       Alvim      alvins.titi28@gmail.com     28   Florianópolis
# 6     Bruna       Silva        Brunasisi44@gmail.com     27       São Paulo
# 7  Fernando  Diamantino  Fernandin.diam878@gmail.com     23    Porto Alegre
# 8     Paula   Fernandes       paulaF.nades@gmail.com     29           Belém
# 9    Thiago   Guimarães     guimares.tiago@gmail.com     35       São Paulo
#
#   Filhos  Altura        Atuação    Sexo Situacao
# 0      N    1.80     Tecnologia   Homem     Alto
# ...

# %%
pd.DataFrame(dados['Cidade'].value_counts())
# Out:
#                 Cidade
# São Paulo            4
# Porto Seguro         1
# Porto Alegre         1
# Rio de Janeiro       1
# Florianópolis        1
# Belém                1
# Belo Horizonte       1

# %%
dados['Nome'].values
# Out:
# array(['Vitor', 'Amanda', 'Pedro', 'Priscila', 'Joaquim', 'Thiago',
#        'Bruna', 'Fernando', 'Paula', 'Thiago'], dtype=object)

# %%
dados
# Out:
#        Nome   Sobrenome                        Email  Idade          Cidade  \
# 0     Vitor      Duarte    vitor.duartegot@gmail.com     21       São Paulo
# 1    Amanda     Roberta  amanda.robertinha@gmail.com     25       São Paulo
# 2     Pedro       Souza      pedro147.souz@gmail.com     28  Rio de Janeiro
# 3  Priscila     Pereira  priscila.pereira7@gmail.com     30    Porto Seguro
# 4   Joaquim      Vieira     joaq.vieira256@gmail.com     23  Belo Horizonte
# 5    Thiago       Alvim      alvins.titi28@gmail.com     28   Florianópolis
# 6     Bruna       Silva        Brunasisi44@gmail.com     27       São Paulo
# 7  Fernando  Diamantino  Fernandin.diam878@gmail.com     23    Porto Alegre
# 8     Paula   Fernandes       paulaF.nades@gmail.com     29           Belém
# 9    Thiago   Guimarães     guimares.tiago@gmail.com     35       São Paulo
#
#   Filhos  Altura        Atuação    Sexo Situacao
# 0      N    1.80     Tecnologia   Homem     Alto
# ...

# %%
a = dados.groupby('Filhos').mean()

# %%
a
# Out:
#         Idade  Altura
# Filhos
# N        25.2   1.740
# S        28.6   1.784

# %%
dados.drop(dados[dados.Cidade == 'São Paulo'].index)
# Out:
#        Nome   Sobrenome                        Email  Idade          Cidade  \
# 2     Pedro       Souza      pedro147.souz@gmail.com     28  Rio de Janeiro
# 3  Priscila     Pereira  priscila.pereira7@gmail.com     30    Porto Seguro
# 4   Joaquim      Vieira     joaq.vieira256@gmail.com     23  Belo Horizonte
# 5    Thiago       Alvim      alvins.titi28@gmail.com     28   Florianópolis
# 7  Fernando  Diamantino  Fernandin.diam878@gmail.com     23    Porto Alegre
# 8     Paula   Fernandes       paulaF.nades@gmail.com     29           Belém
#
#   Filhos  Altura        Atuação    Sexo Situacao
# 2      S    1.74  Meio Ambiente   Homem     Alto
# 3      S    1.90       Medicina  Mulher     Alto
# 4      N    1.75     Engenharia   Homem     Alto
# 5      N    1.65        Direito   Homem    Baixo
# 7      S    1.84  Biotecnologia   Homem     Alto
# 8      N    1.80       Esportes  Mulher     Alto

# %%
dados.drop(dados[(dados.Cidade == 'São Paulo') & (dados.Sexo == 'Mulher')].index)
# Out:
#        Nome   Sobrenome                        Email  Idade          Cidade  \
# 0     Vitor      Duarte    vitor.duartegot@gmail.com     21       São Paulo
# 2     Pedro       Souza      pedro147.souz@gmail.com     28  Rio de Janeiro
# 3  Priscila     Pereira  priscila.pereira7@gmail.com     30    Porto Seguro
# 4   Joaquim      Vieira     joaq.vieira256@gmail.com     23  Belo Horizonte
# 5    Thiago       Alvim      alvins.titi28@gmail.com     28   Florianópolis
# 7  Fernando  Diamantino  Fernandin.diam878@gmail.com     23    Porto Alegre
# 8     Paula   Fernandes       paulaF.nades@gmail.com     29           Belém
# 9    Thiago   Guimarães     guimares.tiago@gmail.com     35       São Paulo
#
#   Filhos  Altura        Atuação    Sexo Situacao
# 0      N    1.80     Tecnologia   Homem     Alto
# 2      S    1.74  Meio Ambiente   Homem     Alto
# 3      S    1.90       Medicina  Mulher     Alto
# 4      N    1.75     Engenharia   Homem     Alto
# ...

# %%
data = pd.DataFrame({'A': [1,2,3,4,5,6,7,8,9],
                     'B': [1,5,8,7,4,6,3,2,9],
                     'C': [0,5,8,9,7,4,6,3,2],
                     'D': [7,2,0,1,4,5,8,9,6]})
data
# Out:
#    A  B  C  D
# 0  1  1  0  7
# 1  2  5  5  2
# 2  3  8  8  0
# 3  4  7  9  1
# 4  5  4  7  4
# 5  6  6  4  5
# 6  7  3  6  8
# 7  8  2  3  9
# 8  9  9  2  6

# %%
import numpy as np

# %%
framen =pd.DataFrame(data = np.random.randint(0,100,100).reshape(10,10), columns='A B C D E F G H I J'.split())
framen
# Out:
#     A   B   C   D   E   F   G   H   I   J
# 0  70  16  70  76  63  68  49  57  35  50
# 1  26  34   4  12  70  39   2  32  63  71
# 2  53  11  70   6  41  79  48  11  33  47
# 3  78   5  18  92  30  63  35   2  33  58
# 4  14  44  67  79  70  92  35  97  12  78
# 5  43  58  69  77  79  81  23  91  44   3
# 6  89  25  44  70  24  33  61  72  63  35
# 7  77  82  83  32  42  81  81  55  68  55
# 8  44  90  76  13  79  91  62  33  27  68
# 9  41  81  40   9  76  33  45  19   6  56

# %%
framen[(framen.A > 15)]
# Out:
#     A   B   C   D   E   F   G   H   I   J
# 0  46  98  81  36  35   4  29  33  56  80
# 1  67  89   5  96   8  62  98  76  50  72
# 3  81  11   6  93  68  78  89  68  73   7
# 4  89  31  10  17  94  32  67  63  61  13
# 8  77  34   5  35  92  28  86  27   7  95

# %%
framen[(framen.A > 15) & (framen.J == 7)]
# Out:
#     A   B  C   D   E   F   G   H   I  J
# 3  81  11  6  93  68  78  89  68  73  7

# %%
data = pd.DataFrame({'A': {'a': 1, 'b': 2},
                     'B': {'b':2, 'c': 3}})
data
# Out:
#      A    B
# a  1.0  NaN
# b  2.0  2.0
# c  NaN  3.0

# %%
#data['A'].fillna(0, inplace = True)

# %%
data.loc['c','A'] = 0

# %%
data
# Out:
#      A    B
# a  1.0  NaN
# b  2.0  2.0
# c  0.0  3.0

# %%
dados.groupby('Filhos').mean()
# Out:
#         Idade  Altura
# Filhos
# N        25.2   1.740
# S        28.6   1.784

# %%
dados.describe()
# Out:
#            Idade     Altura
# count  10.000000  10.000000
# mean   26.900000   1.762000
# std     4.094712   0.074803
# min    21.000000   1.650000
# 25%    23.500000   1.710000
# 50%    27.500000   1.750000
# 75%    28.750000   1.800000
# max    35.000000   1.900000

# %%
dados.mean()
# Out:
# Idade     26.900
# Altura     1.762
# dtype: float64

# %%
dados.loc[8,'Nome'] = 'Paulinha'

# %%
dados
# Out:
#        Nome   Sobrenome                        Email  Idade          Cidade  \
# 0     Vitor      Duarte    vitor.duartegot@gmail.com     21       São Paulo
# 1    Amanda     Roberta  amanda.robertinha@gmail.com     25       São Paulo
# 2     Pedro       Souza      pedro147.souz@gmail.com     28  Rio de Janeiro
# 3  Priscila     Pereira  priscila.pereira7@gmail.com     30    Porto Seguro
# 4   Joaquim      Vieira     joaq.vieira256@gmail.com     23  Belo Horizonte
# 5    Thiago       Alvim      alvins.titi28@gmail.com     28   Florianópolis
# 6     Bruna       Silva        Brunasisi44@gmail.com     27       São Paulo
# 7  Fernando  Diamantino  Fernandin.diam878@gmail.com     23    Porto Alegre
# 8  Paulinha   Fernandes       paulaF.nades@gmail.com     29           Belém
# 9    Thiago   Guimarães     guimares.tiago@gmail.com     35       São Paulo
#
#   Filhos  Altura        Atuação
# 0      N    1.80     Tecnologia
# 1      N    1.70          Saúde
# 2      S    1.74  Meio Ambiente
# ...

# %% [markdown]
# # CRIANDO DATAFRAMA COM UMA CLASSE E ATRIBUTOS

# %%
dados2 = pd.DataFrame(columns = ['Nome','Idade','Profissão','Motivo no programa','Após o Prêmio'])
dados2

class Pessoa1:
    def __init__(self):
        self.nome = 'Alexandre'
        self.idade = 29
        self.profissao = 'Professor'
        self.motivo = 'Passar mais conhecimento'
        self.dinheiro ='Abrir uma escola'
        
Alexandre = Pessoa1()

dados2.loc[0,'Nome':'Após o Prêmio'] = Alexandre.nome,Alexandre.idade,Alexandre.profissao,Alexandre.motivo,Alexandre.dinheiro
dados2
# Out:
#         Nome Idade  Profissão        Motivo no programa     Após o Prêmio
# 0  Alexandre    29  Professor  Passar mais conhecimento  Abrir uma escola

# %%
treino = pd.DataFrame({'Notas':[2,4,8,9,6,8,8],
                       'Notas2':[1,4,5,4,5,4,3]})
treino
# Out:
#    Notas  Notas2
# 0      2       1
# 1      4       4
# 2      8       5
# 3      9       4
# 4      6       5
# 5      8       4
# 6      8       3

# %%
treino.mean()
# Out:
# Notas     6.428571
# Notas2    3.714286
# dtype: float64

# %%
treino.mode()
# Out:
#    Notas  Notas2
# 0      8       4

# %%
treino.median()
# Out:
# Notas     8.0
# Notas2    4.0
# dtype: float64

# %%
import seaborn as sns

# %%
sns.distplot(treino.Notas2)
